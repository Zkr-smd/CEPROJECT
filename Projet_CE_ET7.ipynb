# %% [markdown]
# <a href="https://colab.research.google.com/github/Zkr-smd/CEPROJECT/blob/main/Projet_CE_ET7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt

# %%
# Lire les fichiers texte
with open("/content/training.txt", "r") as f:
    training_raw = f.read()

with open("/content/test.txt", "r") as f:
    test_raw = f.read()

# %%
import re
import numpy as np

def parse_c_array_to_numpy(text, nb_samples, frames, coeffs):
    # Récupère tous les floats
    floats = [float(x) for x in re.findall(r"[-+]?[0-9]*\.?[0-9]+", text)]

    # Tronquer si trop de valeurs
    expected_len = nb_samples * frames * coeffs
    floats = floats[:expected_len]

    return np.array(floats).reshape((nb_samples, frames, coeffs))


# Training : 100 enregistrements, 48 frames, 13 coefficients MFCC
X_train = parse_c_array_to_numpy(training_raw, 100, 48, 13)

# Test : 10 enregistrements, 48 frames, 13 coefficients MFCC
X_test = parse_c_array_to_numpy(test_raw, 10, 48, 13)

# %%
# Chargement des données
X_train = parse_c_array_to_numpy(training_raw, 100, 48, 13)
X_test = parse_c_array_to_numpy(test_raw, 10, 48, 13)

# Ajout de la dimension canal
X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]

# Création des étiquettes
y_train = np.array([0]*50 + [1]*50)  # 0 = Rouge, 1 = Bleu
y_test = np.array([0]*5 + [1]*5)

print("Train shape :", X_train.shape, y_train.shape)
print("Test shape  :", X_test.shape, y_test.shape)
# Out:
# Train shape : (100, 48, 13, 1) (100,)
# Test shape  : (10, 48, 13, 1) (10,)

# %%
model = models.Sequential([
    layers.Input(shape=(48, 13, 1)),
    layers.Conv2D(8, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(16, activation='relu'),
    layers.Dense(1, activation='sigmoid')  # Binaire : Bleu ou Rouge
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['mse', 'accuracy'])

model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 46, 11, 8)      │            80 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 23, 5, 8)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 920)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 16)             │        14,736 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,833 (57.94 KB)
#  Trainable params: 14,833 (57.94 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X_train, y_train,
                    epochs=50,
                    batch_size=8,
                    validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.4816 - loss: 0.7265 - mse: 0.2568 - val_accuracy: 0.5000 - val_loss: 0.6780 - val_mse: 0.2429
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5030 - loss: 0.6940 - mse: 0.2505 - val_accuracy: 0.8000 - val_loss: 0.6111 - val_mse: 0.2153
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8623 - loss: 0.6600 - mse: 0.2342 - val_accuracy: 0.6000 - val_loss: 0.5963 - val_mse: 0.2096
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6242 - loss: 0.6404 - mse: 0.2250 - val_accuracy: 0.5000 - val_loss: 0.5975 - val_mse: 0.2111
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5370 - loss: 0.6674 - mse: 0.2382 - val_accuracy: 0.8000 - val_loss: 0.5892 - val_mse: 0.2067
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6042 - loss: 0.6475 - mse: 0.2289 - val_accuracy: 0.6000 - val_loss: 0.5818 - val_mse: 0.2024
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7156 - loss: 0.6349 - mse: 0.2212 - val_accuracy: 0.8000 - val_loss: 0.5762 - val_mse: 0.2002
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7559 - loss: 0.6132 - mse: 0.2112 - val_accuracy: 1.0000 - val_loss: 0.5518 - val_mse: 0.1877
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7142 - loss: 0.6067 - mse: 0.2078 - val_accuracy: 1.0000 - val_loss: 0.5374 - val_mse: 0.1809
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8881 - loss: 0.5878 - mse: 0.1997 - val_accuracy: 1.0000 - val_loss: 0.5162 - val_mse: 0.1707
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9481 - loss: 0.5594 - mse: 0.1849 - val_accuracy: 1.0000 - val_loss: 0.4912 - val_mse: 0.1590
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9620 - loss: 0.5235 - mse: 0.1681 - val_accuracy: 1.0000 - val_loss: 0.4482 - val_mse: 0.1383
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8949 - loss: 0.5078 - mse: 0.1605 - val_accuracy: 1.0000 - val_loss: 0.4246 - val_mse: 0.1291
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8761 - loss: 0.4650 - mse: 0.1435 - val_accuracy: 1.0000 - val_loss: 0.3768 - val_mse: 0.1059
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9369 - loss: 0.4264 - mse: 0.1249 - val_accuracy: 0.9000 - val_loss: 0.3962 - val_mse: 0.1237
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9039 - loss: 0.4347 - mse: 0.1296 - val_accuracy: 1.0000 - val_loss: 0.2958 - val_mse: 0.0721
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9495 - loss: 0.3562 - mse: 0.0968 - val_accuracy: 1.0000 - val_loss: 0.2879 - val_mse: 0.0733
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9673 - loss: 0.3137 - mse: 0.0797 - val_accuracy: 1.0000 - val_loss: 0.2276 - val_mse: 0.0472
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9649 - loss: 0.2980 - mse: 0.0773 - val_accuracy: 1.0000 - val_loss: 0.2564 - val_mse: 0.0723
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8440 - loss: 0.4054 - mse: 0.1293 - val_accuracy: 1.0000 - val_loss: 0.1782 - val_mse: 0.0312
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9294 - loss: 0.2876 - mse: 0.0775 - val_accuracy: 1.0000 - val_loss: 0.2107 - val_mse: 0.0494
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9003 - loss: 0.2803 - mse: 0.0803 - val_accuracy: 1.0000 - val_loss: 0.1488 - val_mse: 0.0231
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9501 - loss: 0.1939 - mse: 0.0428 - val_accuracy: 1.0000 - val_loss: 0.1694 - val_mse: 0.0342
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9713 - loss: 0.1945 - mse: 0.0423 - val_accuracy: 1.0000 - val_loss: 0.1207 - val_mse: 0.0172
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9545 - loss: 0.1886 - mse: 0.0461 - val_accuracy: 1.0000 - val_loss: 0.1109 - val_mse: 0.0143
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9708 - loss: 0.1726 - mse: 0.0401 - val_accuracy: 0.9000 - val_loss: 0.2164 - val_mse: 0.0603
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8680 - loss: 0.2889 - mse: 0.0937 - val_accuracy: 1.0000 - val_loss: 0.1422 - val_mse: 0.0282
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9224 - loss: 0.2524 - mse: 0.0712 - val_accuracy: 1.0000 - val_loss: 0.0930 - val_mse: 0.0106
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9437 - loss: 0.1735 - mse: 0.0439 - val_accuracy: 1.0000 - val_loss: 0.1054 - val_mse: 0.0153
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9647 - loss: 0.1707 - mse: 0.0421 - val_accuracy: 1.0000 - val_loss: 0.0972 - val_mse: 0.0142
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9282 - loss: 0.2210 - mse: 0.0605 - val_accuracy: 1.0000 - val_loss: 0.0871 - val_mse: 0.0106
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9642 - loss: 0.1622 - mse: 0.0419 - val_accuracy: 1.0000 - val_loss: 0.0727 - val_mse: 0.0071
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9461 - loss: 0.1450 - mse: 0.0372 - val_accuracy: 1.0000 - val_loss: 0.0839 - val_mse: 0.0109
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9610 - loss: 0.1289 - mse: 0.0315 - val_accuracy: 1.0000 - val_loss: 0.1044 - val_mse: 0.0183
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9436 - loss: 0.1462 - mse: 0.0373 - val_accuracy: 1.0000 - val_loss: 0.0612 - val_mse: 0.0050
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9364 - loss: 0.1556 - mse: 0.0430 - val_accuracy: 1.0000 - val_loss: 0.0632 - val_mse: 0.0058
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9702 - loss: 0.1044 - mse: 0.0246 - val_accuracy: 1.0000 - val_loss: 0.0579 - val_mse: 0.0047
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9026 - loss: 0.2078 - mse: 0.0615 - val_accuracy: 1.0000 - val_loss: 0.0569 - val_mse: 0.0046
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9645 - loss: 0.1110 - mse: 0.0265 - val_accuracy: 1.0000 - val_loss: 0.0535 - val_mse: 0.0037
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9493 - loss: 0.1517 - mse: 0.0410 - val_accuracy: 1.0000 - val_loss: 0.1349 - val_mse: 0.0314
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9466 - loss: 0.1587 - mse: 0.0438 - val_accuracy: 1.0000 - val_loss: 0.1031 - val_mse: 0.0198
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9644 - loss: 0.1217 - mse: 0.0274 - val_accuracy: 1.0000 - val_loss: 0.0672 - val_mse: 0.0072
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9399 - loss: 0.1915 - mse: 0.0591 - val_accuracy: 1.0000 - val_loss: 0.0475 - val_mse: 0.0031
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9028 - loss: 0.2065 - mse: 0.0659 - val_accuracy: 1.0000 - val_loss: 0.1409 - val_mse: 0.0341
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9301 - loss: 0.1750 - mse: 0.0513 - val_accuracy: 1.0000 - val_loss: 0.0459 - val_mse: 0.0030
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9722 - loss: 0.0930 - mse: 0.0222 - val_accuracy: 1.0000 - val_loss: 0.0457 - val_mse: 0.0030
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9581 - loss: 0.1256 - mse: 0.0366 - val_accuracy: 1.0000 - val_loss: 0.1145 - val_mse: 0.0245
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9918 - loss: 0.0806 - mse: 0.0167 - val_accuracy: 1.0000 - val_loss: 0.0492 - val_mse: 0.0040
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9869 - loss: 0.0716 - mse: 0.0130 - val_accuracy: 1.0000 - val_loss: 0.0637 - val_mse: 0.0081
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9358 - loss: 0.1439 - mse: 0.0449 - val_accuracy: 1.0000 - val_loss: 0.0554 - val_mse: 0.0059

# %%
plt.plot(history.history['mse'], label='Train MSE')
plt.plot(history.history['val_mse'], label='Test MSE')
plt.xlabel("Epoch")
plt.ylabel("Erreur quadratique moyenne")
plt.legend()
plt.title("Évolution de l'erreur")
plt.grid(True)
plt.show()
